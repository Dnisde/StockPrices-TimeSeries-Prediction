# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA, KernelPCA
from sklearn.metrics import explained_variance_score
from sklearn.datasets import load_diabetes
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
diabetes = load_diabetes()
X = diabetes.data
y = diabetes.target

# %%
pca = PCA(n_components=0.9) # "mle" or number or ratio
x_dr = pca.fit_transform(X)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.40242142, 0.14923182, 0.12059623, 0.09554764, 0.06621856,
#        0.06027192, 0.05365605])

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.40242142, 0.55165324, 0.67224947, 0.76779711, 0.83401567,
#        0.89428759, 0.94794364])

# %%
plt.plot([1,2,3,4,5,6,7], np.cumsum(pca.explained_variance_ratio_))
plt.xticks([1,2,3,4,5,6,7])
plt.show()

# %%
import pandas as pd
import pylab as pl
from sklearn import datasets
from sklearn.decomposition import PCA

# %%
# load dataset
diabetes = datasets.load_diabetes()
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
df

# %%
# normalize data
from sklearn import preprocessing
data_scaled = pd.DataFrame(preprocessing.scale(df),columns = df.columns)

# %%
# PCA
pca = PCA(n_components=0.9)
pca.fit_transform(data_scaled)

# %%
# Dump components relations with features:
print(pd.DataFrame(pca.components_,columns=data_scaled.columns))
# Out:
#         age       sex       bmi  ...        s4        s5        s6
# 0  0.216431  0.186967  0.303162  ...  0.428833  0.378617  0.322183
# 1  0.044372 -0.386548 -0.156281  ... -0.068184 -0.026189 -0.084947
# 2  0.494668 -0.106858  0.167532  ... -0.380681  0.063632  0.276843
# 3 -0.414009 -0.679861  0.499825  ...  0.007921  0.264427  0.087086
# 4 -0.686864  0.373456  0.129359  ... -0.143644 -0.151661  0.031388
# 5 -0.225851  0.041731 -0.403142  ... -0.033945  0.178730  0.805064
# 6 -0.109538 -0.067606 -0.519858  ...  0.071236  0.647313 -0.357273
#
# [7 rows x 10 columns]

# %%
from sklearn.decomposition import PCA
import pandas as pd
from sklearn import datasets
import numpy as np
diabetes = datasets.load_diabetes()
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
# normalize data
from sklearn import preprocessing
data_scaled = pd.DataFrame(preprocessing.scale(df),columns = df.columns)

# %%
# PCA
pca = PCA(n_components="mle")
pca.fit_transform(data_scaled)
# Out:
# array([[ 0.58720767, -1.94682793,  0.58923299, ..., -0.17980726,
#          0.75744463, -0.18107712],
#        [-2.83161209,  1.37208454,  0.02791506, ...,  0.22441384,
#         -0.18840749,  0.50511975],
#        [ 0.27214757, -1.63489803,  0.73927034, ..., -0.46240604,
#          0.84323498, -0.0253607 ],
#        ...,
#        [-0.20524634, -1.20544647,  0.4960784 , ..., -0.63545068,
#         -0.49169045, -0.11323793],
#        [ 0.69286627,  0.21011694, -0.86872976, ...,  0.54570255,
#          0.07867558, -0.12721134],
#        [-1.90393365,  3.97577106, -0.04838108, ...,  0.24526495,
#          1.18537538,  0.73046601]])

# %%
pca.components_

# %%
# number of components
n_pcs= pca.components_.shape[0]

# get the index of the most important feature on EACH component i.e. largest absolute value
# using LIST COMPREHENSION HERE
most_important = [np.abs(pca.components_[i]).argmax() for i in range(n_pcs)]
most_important
# Out:
# [7, 4, 3, 1, 0, 9, 8, 3, 7]

# %%
initial_feature_names = diabetes.feature_names
initial_feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
# get the names
most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]
most_important_names
# Out:
# ['s4', 's1', 'bp', 'sex', 'age', 's6', 's5', 'bp', 's4']

# %%
# using LIST COMPREHENSION HERE AGAIN
dic = {'PC{}'.format(i+1): most_important_names[i] for i in range(n_pcs)}

# build the dataframe
df = pd.DataFrame(sorted(dic.items()))
df
# Out:
#      0    1
# 0  PC1   s4
# 1  PC2   s1
# 2  PC3   bp
# 3  PC4  sex
# 4  PC5  age
# 5  PC6   s6
# 6  PC7   s5
# 7  PC8   bp
# 8  PC9   s4

# %%
from sklearn.decomposition import PCA
import pandas as pd
from sklearn import datasets
import numpy as np
diabetes = datasets.load_diabetes()
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
# normalize data
from sklearn import preprocessing
data_scaled = pd.DataFrame(preprocessing.scale(df),columns = df.columns)
# pca
pca = PCA(n_components="mle")
# number of components
n_pcs= pca.components_.shape[0]

# get the index of the most important feature on EACH component i.e. largest absolute value
# using LIST COMPREHENSION HERE
most_important = [np.abs(pca.components_[i]).argmax() for i in range(n_pcs)]
